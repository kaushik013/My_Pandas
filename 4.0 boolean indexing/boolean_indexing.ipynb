# %% [markdown]
# # boolean indexing

# %%
import numpy as np 
import pandas as pd

# %%
cricket = pd.read_csv('../8_files/kohli_ipl.csv',index_col='match_no')
cricket
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
cricket[cricket['runs'] >= 50].count()
# Out:
# runs    50
# dtype: int64

# %%
subs = pd.read_csv('../8_files/subs.csv')
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs[subs['Subscribers gained'] >= 200].count()
# Out:
# Subscribers gained    59
# dtype: int64

# %%
movie = pd.read_csv('../8_files/bollywood.csv',index_col='movie')
movie
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
num_movie = movie.value_counts()
num_movie[num_movie > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movie.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>
