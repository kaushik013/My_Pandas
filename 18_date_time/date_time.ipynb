# %%
import numbers as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
pd.Timestamp('2026/1/2')
# Out:
# Timestamp('2026-01-02 00:00:00')

# %%
pd.Timestamp('2026')
# Out:
# Timestamp('2026-01-01 00:00:00')

# %%
pd.Timestamp('2/2/2026')
# Out:
# Timestamp('2026-02-02 00:00:00')

# %%
pd.Timestamp('2nd feb 2026')
# Out:
# Timestamp('2026-02-02 00:00:00')

# %%
pd.Timestamp('2026/2/2 12:32 AM')
# Out:
# Timestamp('2026-02-02 00:32:00')

# %%
index  = pd.DatetimeIndex(['2026/01/01','2026/01/02','2026/01/03'])

pd.Series([1,2,3],index=index)
# Out:
# 2026-01-01    1
# 2026-01-02    2
# 2026-01-03    3
# dtype: int64

# %% [markdown]
# # date_range function

# %%
# generate date time 
pd.date_range(start='2026/02/01',end='2026/02/28')
# Out:
# DatetimeIndex(['2026-02-01', '2026-02-02', '2026-02-03', '2026-02-04',
#                '2026-02-05', '2026-02-06', '2026-02-07', '2026-02-08',
#                '2026-02-09', '2026-02-10', '2026-02-11', '2026-02-12',
#                '2026-02-13', '2026-02-14', '2026-02-15', '2026-02-16',
#                '2026-02-17', '2026-02-18', '2026-02-19', '2026-02-20',
#                '2026-02-21', '2026-02-22', '2026-02-23', '2026-02-24',
#                '2026-02-25', '2026-02-26', '2026-02-27', '2026-02-28'],
#               dtype='datetime64[us]', freq='D')

# %%
pd.date_range(start='2026/03/01',end='2026/03/31',freq='B')
# Out:
# DatetimeIndex(['2026-03-02', '2026-03-03', '2026-03-04', '2026-03-05',
#                '2026-03-06', '2026-03-09', '2026-03-10', '2026-03-11',
#                '2026-03-12', '2026-03-13', '2026-03-16', '2026-03-17',
#                '2026-03-18', '2026-03-19', '2026-03-20', '2026-03-23',
#                '2026-03-24', '2026-03-25', '2026-03-26', '2026-03-27',
#                '2026-03-30', '2026-03-31'],
#               dtype='datetime64[us]', freq='B')

# %%
# only week days -- sunday
pd.date_range(start='2026/03/01',end='2026/03/31',freq='W')
# Out:
# DatetimeIndex(['2026-03-01', '2026-03-08', '2026-03-15', '2026-03-22',
#                '2026-03-29'],
#               dtype='datetime64[us]', freq='W-SUN')

# %%
# only thuresday
pd.date_range(start='2026/03/01',end='2026/03/31',freq='W-THU')
# Out:
# DatetimeIndex(['2026-03-05', '2026-03-12', '2026-03-19', '2026-03-26'], dtype='datetime64[us]', freq='W-THU')

# %%
pd.date_range(start='2026/03/01',end='2026/03/31')
# Out:
# DatetimeIndex(['2026-03-01', '2026-03-02', '2026-03-03', '2026-03-04',
#                '2026-03-05', '2026-03-06', '2026-03-07', '2026-03-08',
#                '2026-03-09', '2026-03-10', '2026-03-11', '2026-03-12',
#                '2026-03-13', '2026-03-14', '2026-03-15', '2026-03-16',
#                '2026-03-17', '2026-03-18', '2026-03-19', '2026-03-20',
#                '2026-03-21', '2026-03-22', '2026-03-23', '2026-03-24',
#                '2026-03-25', '2026-03-26', '2026-03-27', '2026-03-28',
#                '2026-03-29', '2026-03-30', '2026-03-31'],
#               dtype='datetime64[us]', freq='D')

# %%
s = pd.Series(['2026/01/01','2026/01/02','2026/01/03'])
s
# Out:
# 0    2026/01/01
# 1    2026/01/02
# 2    2026/01/03
# dtype: str

# %%
new = pd.to_datetime(s)

# %%
new.dt.year
# Out:
# 0    2026
# 1    2026
# 2    2026
# dtype: int32

# %%
new.dt.month
# Out:
# 0    1
# 1    1
# 2    1
# dtype: int32

# %%
new.dt.day
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int32

# %%
# with error 
s = pd.Series(['2026/01/01','2026/01/02','2026/01/030'])
pd.to_datetime(s,errors='coerce')
# Out:
# 0   2026-01-01
# 1   2026-01-02
# 2          NaT
# dtype: datetime64[us]

# %%
data_date = pd.read_csv('../8_files/expense_data.csv')
data_date.head(1)
# Out:
#              Date               Account Category  Subcategory     Note   INR  \
# 0  3/2/2022 10:11  CUB - online payment     Food          NaN  Brownie  50.0
#
#   Income/Expense  Note.1  Amount Currency  Account.1
# 0        Expense     NaN    50.0      INR       50.0

# %%
data_date.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    str
#  1   Account         277 non-null    str
#  2   Category        277 non-null    str
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    str
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    str
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    str
#  10  Account.1       277 non-null    float64
# dtypes: float64(5), str(6)
# memory usage: 23.9 KB

# %%
data_date['Date'] = pd.to_datetime(data_date['Date'])

# %%
data_date.head(1)
# Out:
#                  Date               Account Category  Subcategory     Note  \
# 0 2022-03-02 10:11:00  CUB - online payment     Food          NaN  Brownie
#
#     INR Income/Expense  Note.1  Amount Currency  Account.1
# 0  50.0        Expense     NaN    50.0      INR       50.0

# %%
data_date['Date'].dt.year
# Out:
# 0      2022
# 1      2022
# 2      2022
# 3      2022
# 4      2022
#        ...
# 272    2021
# 273    2021
# 274    2021
# 275    2021
# 276    2021
# Name: Date, Length: 277, dtype: int32

# %%
plt.plot(data_date['Date'],data_date['INR'])

# %%
data_date['day_name'] = data_date['Date'].dt.day_name()

# %%
data_date.groupby('day_name')['INR'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='day_name'>
