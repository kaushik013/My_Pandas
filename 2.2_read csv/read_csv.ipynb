# %% [markdown]
# # read csv

# %%
import numpy as np 
import pandas as pd

# %%
type(pd.read_csv('../8_files/subs.csv'))
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # with one column

# %%
data = pd.read_csv('../8_files/subs.csv')
data
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %% [markdown]
# # with two column

# %%
cricket = pd.read_csv('../8_files/kohli_ipl.csv',index_col='match_no')
cricket
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
movie = pd.read_csv('../8_files/bollywood.csv',index_col='movie')
movie
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %% [markdown]
# # methods

# %% [markdown]
# ### head()

# %%
movie.head()
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar

# %%
# if we pass number in head so it will return number of data to head 
data.head(6)
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44
# 5                  46

# %% [markdown]
# # tail()

# %%
data.tail()
# Out:
#      Subscribers gained
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172

# %%
# if we pass number in tail so it will return number of data to tail 
data.tail(10)
# Out:
#      Subscribers gained
# 355                 149
# 356                 156
# 357                 177
# 358                 210
# 359                 209
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172

# %% [markdown]
# # sample( ) --- > it will return the 1 random row

# %%
data.sample()
# Out:
#      Subscribers gained
# 314                 150

# %% [markdown]
# # valuecount() -- > it will return the count of value

# %%
movie.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Kashmira Shah        1
# Kartik Elangovan     1
# Karisma Kapoor       1
# Karan Sharma         1
# Zulfi Sayed          1
# Name: count, Length: 566, dtype: int64

# %% [markdown]
# # sort_values()  --- > sort the value default assending

# %%
cricket.sort_values(by='runs',ascending=False).head(1).values[0]
# Out:
# array([113])

# %%
movie.sort_index()
# Out:
#                                         lead
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: London                   Sharman Joshi
# 1920: The Evil Returns           Vicky Ahuja
# 1971 (2007 film)              Manoj Bajpayee
# 2 States (2014 film)            Arjun Kapoor
# ...                                      ...
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
#
# [1500 rows x 1 columns]
