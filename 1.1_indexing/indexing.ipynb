# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# # indexing

# %%
a = pd.Series([11,12,13,14,15])
a
# Out:
# 0    11
# 1    12
# 2    13
# 3    14
# 4    15
# dtype: int64

# %%
a[0]
# Out:
# np.int64(11)

# %%
a[1]
# Out:
# np.int64(12)
