# %%
import numpy as np 
import pandas as pd

# %%
data = pd.read_csv('../8_files/kohli_ipl.csv')
data
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %% [markdown]
# # count( )

# %%
data.count()
# Out:
# match_no    215
# runs        215
# dtype: int64

# %%
data['runs'].count()
# Out:
# np.int64(215)

# %% [markdown]
# # sum()

# %%
subs = pd.read_csv('../8_files/subs.csv')
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs['Subscribers gained'].sum()
# Out:
# np.int64(49510)

# %% [markdown]
# # mean()  ---> avg

# %%
subs['Subscribers gained'].mean()
# Out:
# np.float64(135.64383561643837)

# %% [markdown]
# # mediun() -- >  Median is the middle value of sorted data.

# %%
data['runs'].median()
# Out:
# np.float64(24.0)

# %%
movie = pd.read_csv('../8_files/bollywood.csv')

# %% [markdown]
# # mode () --->  can return multiple values if there is a tie

# %%
movie['lead'].mode()
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: object

# %% [markdown]
# # std() ---> Data average ke aas-paas kitna faila hua hai

# %%
data['runs'].std()
# Out:
# np.float64(26.22980132830278)

# %% [markdown]
# # min and max()

# %%
data['runs'].max()
# Out:
# np.int64(113)

# %%
data['runs'].min()
# Out:
# np.int64(0)

# %% [markdown]
# # describe --- > return all mathimatical operation (mean,max,min)

# %%
data['runs'].describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64
