# %% [markdown]
# # slicing

# %%
import numpy as np 
import pandas as pd

# %%
data = pd.read_csv('../8_files/kohli_ipl.csv',index_col='match_no')

# %%
data
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
data[6:11]
# Out:
#           runs
# match_no
# 7           34
# 8            0
# 9           21
# 10           3
# 11          10

# %%
data[-5:]
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %% [markdown]
# # fancy indexing

# %%
data['runs'][[1,2,3]]
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# Name: runs, dtype: int64

# %%
data['runs'][1] = 10

# %%
data.head(1)
# Out:
#           runs
# match_no
# 1           10

# %%
data['runs'][[1,3,5]] = [12,13,14]

# %%
data
# Out:
#           runs
# match_no
# 1           12
# 2           23
# 3           13
# 4           12
# 5           14
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]
