# %%
import pandas as pd

# %%
df=pd.read_html('https://www.netflix.com/tudum/top10/tv')

# %%
df
# Out:
# [                                             Ranking  Unnamed: 1     Views  \
#  0                                01Stranger Things 5           2  23600000
#  1              02Sean Combs: The Reckoning: Season 1           1  21800000
#  2                        03Stranger Things: Season 1          16   8200000
#  3                           04The Abandons: Season 1           1   7300000
#  4                                05Stranger Things 2          14   6800000
#  5                                06Stranger Things 3          14   5900000
#  6                                07Stranger Things 4          22   5300000
#  7                         08The Rats: A Witcher Tale           1   5000000
#  8                  09The Beast in Me: Limited Series           4   4800000
#  9  10Matt Rife: Unwrapped - A Christmas Crowd Wor...           1   4600000
#
#    Runtime  Hours Viewed
#  0    4:46     112700000
#  1    4:08      89900000
#  2    6:49      56100000
#  3    5:05      37000000
# ...

# %%
import bs4
import requests
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0: Win64: x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"}
rec=requests.get('https://www.imdb.com/chart/top/?ref_=hm_nv_menu',headers=headers)
rec
# Out:
# <Response [200]>

# %%
soup=bs4.BeautifulSoup(rec.text,'lxml')

# %%
# soup

# %%
li=soup.find_all('li',class_='ipc-metadata-list-summary-item')
# li

# %%
for i in li:
  name=i.find('h3',class_='ipc-title__text')
  print(name.text)
# Out:
# The Shawshank Redemption
# The Godfather
# The Dark Knight
# The Godfather Part II
# 12 Angry Men
# The Lord of the Rings: The Return of the King
# Schindler's List
# The Lord of the Rings: The Fellowship of the Ring
# Pulp Fiction
# The Good, the Bad and the Ugly
# The Lord of the Rings: The Two Towers
# Forrest Gump
# Fight Club
# Inception
# Star Wars: Episode V - The Empire Strikes Back
# The Matrix
# Goodfellas
# Interstellar
# One Flew Over the Cuckoo's Nest
# Se7en
# It's a Wonderful Life
# The Silence of the Lambs
# Seven Samurai
# Saving Private Ryan
# The Green Mile
