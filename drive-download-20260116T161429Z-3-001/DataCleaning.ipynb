# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/amazon_fires.csv',encoding='latin')
df
# Out:
#        ano       mes     estado   numero  encontro
# 0     1998   Janeiro       Acre  0 Fires  1/1/1998
# 1     1999   Janeiro       Acre  0 Fires  1/1/1999
# 2     2000   Janeiro       Acre  0 Fires  1/1/2000
# 3     2001   Janeiro       Acre  0 Fires  1/1/2001
# 4     2002   Janeiro       Acre  0 Fires  1/1/2002
# ...    ...       ...        ...      ...       ...
# 6449  2012  Dezembro  Tocantins      128  1/1/2012
# 6450  2013  Dezembro  Tocantins       85  1/1/2013
# 6451  2014  Dezembro  Tocantins      223  1/1/2014
# 6452  2015  Dezembro  Tocantins      373  1/1/2015
# 6453  2016  Dezembro  Tocantins      119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['ano', 'mes', 'estado', 'numero', 'encontro'], dtype='object')

# %%
d = {'ano':'year', 'mes':'month', 'estado':'state', 'numero':'nmbers', 'encontro':'date'}
df.rename(columns=d,inplace=True)
df
# Out:
#       year     month      state   nmbers      date
# 0     1998   Janeiro       Acre  0 Fires  1/1/1998
# 1     1999   Janeiro       Acre  0 Fires  1/1/1999
# 2     2000   Janeiro       Acre  0 Fires  1/1/2000
# 3     2001   Janeiro       Acre  0 Fires  1/1/2001
# 4     2002   Janeiro       Acre  0 Fires  1/1/2002
# ...    ...       ...        ...      ...       ...
# 6449  2012  Dezembro  Tocantins      128  1/1/2012
# 6450  2013  Dezembro  Tocantins       85  1/1/2013
# 6451  2014  Dezembro  Tocantins      223  1/1/2014
# 6452  2015  Dezembro  Tocantins      373  1/1/2015
# 6453  2016  Dezembro  Tocantins      119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       year     month      state   nmbers      date
# 0     1998   Janeiro       Acre  0 Fires  1/1/1998
# 1     1999   Janeiro       Acre  0 Fires  1/1/1999
# 2     2000   Janeiro       Acre  0 Fires  1/1/2000
# 3     2001   Janeiro       Acre  0 Fires  1/1/2001
# 4     2002   Janeiro       Acre  0 Fires  1/1/2002
# ...    ...       ...        ...      ...       ...
# 6449  2012  Dezembro  Tocantins      128  1/1/2012
# 6450  2013  Dezembro  Tocantins       85  1/1/2013
# 6451  2014  Dezembro  Tocantins      223  1/1/2014
# 6452  2015  Dezembro  Tocantins      373  1/1/2015
# 6453  2016  Dezembro  Tocantins      119  1/1/2016
#
# [6424 rows x 5 columns]

# %%
df['month'].unique()
# Out:
# array(['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho',
#        'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro'],
#       dtype=object)

# %%
d1 = {'Janeiro':'January', 'Fevereiro':'February', 'Março':'March', 'Abril':"April", 'Maio':"May", 'Junho':"June", 'Julho':"July",
       'Agosto':"August", 'Setembro':"September", 'Outubro':"October", 'Novembro':"November", 'Dezembro':"December"}

# %%
df['month'] = df['month'].map(d1)

# %%
df
# Out:
#       year     month      state   nmbers      date
# 0     1998   January       Acre  0 Fires  1/1/1998
# 1     1999   January       Acre  0 Fires  1/1/1999
# 2     2000   January       Acre  0 Fires  1/1/2000
# 3     2001   January       Acre  0 Fires  1/1/2001
# 4     2002   January       Acre  0 Fires  1/1/2002
# ...    ...       ...        ...      ...       ...
# 6449  2012  December  Tocantins      128  1/1/2012
# 6450  2013  December  Tocantins       85  1/1/2013
# 6451  2014  December  Tocantins      223  1/1/2014
# 6452  2015  December  Tocantins      373  1/1/2015
# 6453  2016  December  Tocantins      119  1/1/2016
#
# [6424 rows x 5 columns]

# %%
# df['month'] = df['month'].str.replace('January','Jan')
df
# Out:
#       year     month      state   nmbers      date
# 0     1998   January       Acre  0 Fires  1/1/1998
# 1     1999   January       Acre  0 Fires  1/1/1999
# 2     2000   January       Acre  0 Fires  1/1/2000
# 3     2001   January       Acre  0 Fires  1/1/2001
# 4     2002   January       Acre  0 Fires  1/1/2002
# ...    ...       ...        ...      ...       ...
# 6449  2012  December  Tocantins      128  1/1/2012
# 6450  2013  December  Tocantins       85  1/1/2013
# 6451  2014  December  Tocantins      223  1/1/2014
# 6452  2015  December  Tocantins      373  1/1/2015
# 6453  2016  December  Tocantins      119  1/1/2016
#
# [6424 rows x 5 columns]

# %%
df['nmbers'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6449    False
# 6450    False
# 6451    False
# 6452    False
# 6453    False
# Name: nmbers, Length: 6424, dtype: bool

# %%
d1 = {'nmbers':'number of fire'}
df.rename(columns=d1,inplace=True)
df
# Out:
#       year     month      state number of fire      date
# 0     1998   January       Acre        0 Fires  1/1/1998
# 1     1999   January       Acre        0 Fires  1/1/1999
# 2     2000   January       Acre        0 Fires  1/1/2000
# 3     2001   January       Acre        0 Fires  1/1/2001
# 4     2002   January       Acre        0 Fires  1/1/2002
# ...    ...       ...        ...            ...       ...
# 6449  2012  December  Tocantins            128  1/1/2012
# 6450  2013  December  Tocantins             85  1/1/2013
# 6451  2014  December  Tocantins            223  1/1/2014
# 6452  2015  December  Tocantins            373  1/1/2015
# 6453  2016  December  Tocantins            119  1/1/2016
#
# [6424 rows x 5 columns]

# %%
df['number of fire'] = df['number of fire'].str.strip(' Fires')
df
# Out:
#       year     month      state number of fire      date
# 0     1998   January       Acre              0  1/1/1998
# 1     1999   January       Acre              0  1/1/1999
# 2     2000   January       Acre              0  1/1/2000
# 3     2001   January       Acre              0  1/1/2001
# 4     2002   January       Acre              0  1/1/2002
# ...    ...       ...        ...            ...       ...
# 6449  2012  December  Tocantins            128  1/1/2012
# 6450  2013  December  Tocantins             85  1/1/2013
# 6451  2014  December  Tocantins            223  1/1/2014
# 6452  2015  December  Tocantins            373  1/1/2015
# 6453  2016  December  Tocantins            119  1/1/2016
#
# [6424 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6424 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            6424 non-null   int64
#  1   month           6424 non-null   object
#  2   state           6424 non-null   object
#  3   number of fire  6292 non-null   object
#  4   date            6424 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 559.2+ KB

# %%
df['month']= df['month'].str.capitalize()

# %%
df
# Out:
#       year     month      state number of fire      date
# 0     1998   January       Acre              0  1/1/1998
# 1     1999   January       Acre              0  1/1/1999
# 2     2000   January       Acre              0  1/1/2000
# 3     2001   January       Acre              0  1/1/2001
# 4     2002   January       Acre              0  1/1/2002
# ...    ...       ...        ...            ...       ...
# 6449  2012  December  Tocantins            128  1/1/2012
# 6450  2013  December  Tocantins             85  1/1/2013
# 6451  2014  December  Tocantins            223  1/1/2014
# 6452  2015  December  Tocantins            373  1/1/2015
# 6453  2016  December  Tocantins            119  1/1/2016
#
# [6424 rows x 5 columns]

# %%
df['number of fire'] = df['number of fire'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6424 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            6424 non-null   int64
#  1   month           6424 non-null   object
#  2   state           6424 non-null   object
#  3   number of fire  6292 non-null   float64
#  4   date            6424 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 559.2+ KB

# %%
# df['number of fire'] = df['number of fire'].astype(int)

# %%
df[df['number of fire'].isnull()]
# Out:
#       year      month      state  number of fire      date
# 68    2006      April       Acre             NaN  1/1/2006
# 110   2008       June       Acre             NaN  1/1/2008
# 127   2005       July       Acre             NaN  1/1/2005
# 206   2004   November       Acre             NaN  1/1/2004
# 217   2015   November       Acre             NaN  1/1/2015
# ...    ...        ...        ...             ...       ...
# 6305  2008        May  Tocantins             NaN  1/1/2008
# 6354  2017       July  Tocantins             NaN  1/1/2017
# 6383  2006  September  Tocantins             NaN  1/1/2006
# 6415  1998   November  Tocantins             NaN  1/1/1998
# 6428  2011   November  Tocantins             NaN  1/1/2011
#
# [132 rows x 5 columns]

# %%
d = {
    'students': ['anas','mitesh','hardik','abhishek',np.nan,'anand','kush','rohit','anas'],
    'roll': [1,np.nan,3,4,np.nan,5,6,7,1],
    'mark':[90,85,np.nan,87,np.nan,92,86,np.nan,90]
}
dfs = pd.DataFrame(d)
dfs
# Out:
#    students  roll  mark
# 0      anas   1.0  90.0
# 1    mitesh   NaN  85.0
# 2    hardik   3.0   NaN
# 3  abhishek   4.0  87.0
# 4       NaN   NaN   NaN
# 5     anand   5.0  92.0
# 6      kush   6.0  86.0
# 7     rohit   7.0   NaN
# 8      anas   1.0  90.0

# %%
m = dfs['mark'].mean()
m
# Out:
# np.float64(88.33333333333333)

# %%
dfs['mark'].fillna(m,inplace=True)
# dfs
# Out:
# /tmp/ipython-input-118985022.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfs['mark'].fillna(m,inplace=True)

# %%
print(dfs)
# Out:
#    students  roll       mark
# 0      anas   1.0  90.000000
# 1    mitesh   NaN  85.000000
# 2    hardik   3.0  88.333333
# 3  abhishek   4.0  87.000000
# 4       NaN   NaN  88.333333
# 5     anand   5.0  92.000000
# 6      kush   6.0  86.000000
# 7     rohit   7.0  88.333333
# 8      anas   1.0  90.000000
