# %% [markdown]
# # math

# %%
import numpy as np 
import pandas as pd

# %%
data1 = {
    'name' : ['kaushik','kajal','yash','dhara','sanjay'],
    'age' : [22,23,21,23,24],
    'dept' : ['IT','HR',"IT",'HR','IT'],
    'cpmpany' : ['Google','TCS','Google','TCS','Amazon']
}

# %%
df = pd.DataFrame(data1)

# %%
df.rename(columns={'cpmpany' : 'company'},inplace=True)

# %%
df['lpa'] = [12,13,14,11,10]

# %%
df.sum()
# Out:
# name       kaushikkajalyashdharasanjay
# age                                113
# dept                        ITHRITHRIT
# company       GoogleTCSGoogleTCSAmazon
# lpa                                 60
# dtype: object

# %%
df['lpa'].mean()
# Out:
# np.float64(12.0)

# %%
df['age'].max()
# Out:
# np.int64(24)

# %%
df['lpa'].min()
# Out:
# np.int64(10)

# %%
df['lpa'].median()
# Out:
# np.float64(12.0)

# %% [markdown]
# # column accessign

# %%
df['company']
# Out:
# 0    Google
# 1       TCS
# 2    Google
# 3       TCS
# 4    Amazon
# Name: company, dtype: object

# %%
# multiple column 
df[['name','age','company']]
# Out:
#       name  age company
# 0  kaushik   22  Google
# 1    kajal   23     TCS
# 2     yash   21  Google
# 3    dhara   23     TCS
# 4   sanjay   24  Amazon

# %%
df.set_index('name',inplace=True)

# %%
df
# Out:
#          age dept company  lpa
# name
# kaushik   22   IT  Google   12
# kajal     23   HR     TCS   13
# yash      21   IT  Google   14
# dhara     23   HR     TCS   11
# sanjay    24   IT  Amazon   10

# %% [markdown]
# # fatch data in row wise
#
# ### iloc & loc

# %%
# single row 
df.iloc[0]
# Out:
# age            22
# dept           IT
# company    Google
# lpa            12
# Name: kaushik, dtype: object

# %%
# multilpe row 
df.iloc[[0,1,2]]
# Out:
#          age dept company  lpa
# name
# kaushik   22   IT  Google   12
# kajal     23   HR     TCS   13
# yash      21   IT  Google   14

# %%
df[0:3]
# Out:
#          age dept company  lpa
# name
# kaushik   22   IT  Google   12
# kajal     23   HR     TCS   13
# yash      21   IT  Google   14

# %%
df.loc[['kaushik','kajal']]
# Out:
#          age dept company  lpa
# name
# kaushik   22   IT  Google   12
# kajal     23   HR     TCS   13

# %%
df.iloc[0:2,0:2]
# Out:
#          age dept
# name
# kaushik   22   IT
# kajal     23   HR

# %%
df.iloc[0:2]
# Out:
#          age dept company  lpa
# name
# kaushik   22   IT  Google   12
# kajal     23   HR     TCS   13

# %%
df.loc['kaushik':'kajal','age':'company']
# Out:
#          age dept company
# name
# kaushik   22   IT  Google
# kajal     23   HR     TCS
